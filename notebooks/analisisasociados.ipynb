# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./../data/2021_analisisasociado.xlsx')

# %%
df
# Out:
#       No. Asociado   CÉDULA                          NOMBRE  ANTIGÜEDAD  \
# 0                1    10000     JORGE ELIECER ALDANA AMADOR           4
# 1                2    11000     ELKIN ARLEY CASTRO VELANDIA           1
# 2                3    12000  HERSSON FERNANDO FLOREZ MORENO           6
# 3                4    13000  BRAYAN ALEXANDER BARON ORTEGON           0
# 4                5    14000    CINDY MAYELA OCHOA HERNANDEZ           5
# ...            ...      ...                             ...         ...
# 2519          2520  2529000                    OFELIA PEREZ          21
# 2520          2521  2530000      DORIS EDIT PARRADO PARRADO           7
# 2521          2522  2531000    LUIS HERLEY JIMENEZ VALENCIA           6
# 2522          2523  2532000  ANGELICA MARIA BLANCO QUINTERO          13
# 2523          2524  2533000        LUIS MIGUEL DIAZ CUBIDES          21
#
#       ACTIVO CIUDAD  EDAD     GÉNERO TIPO VIVIENDA  ESTRATO  ...   PASIVOS  \
# 0     Activo    GRA    54  Masculino     ARRENDADA        2  ...         1
# 1     Activo   GRAN    29  Masculino        PROPIA        2  ...  16000000
# 2     Activo   GRAN    29  Masculino      FAMILIAR        3  ...  84000000
# 3     Activo    ACA    31  Masculino     ARRENDADA        2  ...         0
# 4     Activo   GRAN    34   Femenino        PROPIA        2  ...  67000000
# ...      ...    ...   ...        ...           ...      ...  ...       ...
# 2519  Activo   GRAN    63   Femenino     ARRENDADA        2  ...         0
# 2520  Activo   GRAN    56   Femenino        PROPIA        3  ...         0
# 2521  Activo  VILLA    53  Masculino        PROPIA        3  ...         0
# 2522  Activo  VILLA    43   Femenino        PROPIA        3  ...         0
# 2523  Activo  VILLA    61  Masculino        PROPIA        3  ...         0
#
#      PATRIMONIO  SALARIO   GASTOS       ENTIDAD No. PRODUCTOS CALIFICACIÓN  \
# 0             0  1149906  1000000        GOB MT             1            A
# 1             0  1228925  1000000      EJER NAL             1            A
# 2     -83999999  2319409  1540000        GOB MT             1            A
# 3             0  1854448   900000  MPIO EL DORA             1            A
# 4      83000000  2489102  1000000        GOB MT             1            A
# ...         ...      ...      ...           ...           ...          ...
# 2519          0  1167812        0             0             2            E
# 2520          0  3300000        0             0             1            E
# 2521          0  2402900        0      MUN VCIO             6            E
# 2522          0  5872590        0      MUN VCIO             3            E
# 2523          0  2129772        0             0             1            E
#
#      DIAS MORA  SALDO TOTAL       MORA
# 0            0     492687.0          0
# 1            0     395715.0          0
# 2            0     603910.0          0
# 3            0     631766.0          0
# 4            0          0.0          0
# ...        ...          ...        ...
# 2519       990   12678497.0   52220345
# 2520      1740   26341773.0   55830006
# 2521      1345   26442992.0   75132454
# 2522       865   17119909.0   78433507
# 2523      3630   39753981.0  163603870
#
# [2524 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No. Asociado      2524 non-null   int64
#  1   CÉDULA            2524 non-null   int64
#  2   NOMBRE            2524 non-null   object
#  3   ANTIGÜEDAD        2524 non-null   int64
#  4   ACTIVO            2524 non-null   object
#  5   CIUDAD            2524 non-null   object
#  6   EDAD              2524 non-null   int64
#  7   GÉNERO            2524 non-null   object
#  8   TIPO VIVIENDA     2524 non-null   object
#  9   ESTRATO           2524 non-null   int64
#  10  OCUPACIÓN         2524 non-null   object
#  11  NIVEL ACADÉMICO   2524 non-null   object
#  12  No. HIJOS         2524 non-null   int64
#  13  PERSONAS A CARGO  2524 non-null   object
#  14  TIENE CASA        2524 non-null   object
#  15  TIENE CARRO       2524 non-null   object
#  16  ESTADO CIVIL      2524 non-null   object
#  17  TIPO CONTRATO     2524 non-null   object
#  18  ACTIVOS           2524 non-null   int64
#  19  PASIVOS           2524 non-null   int64
#  20  PATRIMONIO        2524 non-null   int64
#  21  SALARIO           2524 non-null   int64
#  22  GASTOS            2524 non-null   int64
#  23  ENTIDAD           2524 non-null   object
#  24  No. PRODUCTOS     2524 non-null   int64
#  25  CALIFICACIÓN      2524 non-null   object
#  26  DIAS MORA         2524 non-null   int64
#  27  SALDO TOTAL       2524 non-null   float64
#  28  MORA              2524 non-null   int64
# dtypes: float64(1), int64(14), object(14)
# memory usage: 572.0+ KB

# %%
from janitor import clean_names
df = clean_names(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_asociado       2524 non-null   int64
#  1   cedula            2524 non-null   int64
#  2   nombre            2524 non-null   object
#  3   antiguedad        2524 non-null   int64
#  4   activo            2524 non-null   object
#  5   ciudad            2524 non-null   object
#  6   edad              2524 non-null   int64
#  7   genero            2524 non-null   object
#  8   tipo_vivienda     2524 non-null   object
#  9   estrato           2524 non-null   int64
#  10  ocupacion         2524 non-null   object
#  11  nivel_academico   2524 non-null   object
#  12  no_hijos          2524 non-null   int64
#  13  personas_a_cargo  2524 non-null   object
#  14  tiene_casa        2524 non-null   object
#  15  tiene_carro       2524 non-null   object
#  16  estado_civil      2524 non-null   object
#  17  tipo_contrato     2524 non-null   object
#  18  activos           2524 non-null   int64
#  19  pasivos           2524 non-null   int64
#  20  patrimonio        2524 non-null   int64
#  21  salario           2524 non-null   int64
#  22  gastos            2524 non-null   int64
#  23  entidad           2524 non-null   object
#  24  no_productos      2524 non-null   int64
#  25  calificacion      2524 non-null   object
#  26  dias_mora         2524 non-null   int64
#  27  saldo_total       2524 non-null   float64
#  28  mora              2524 non-null   int64
# dtypes: float64(1), int64(14), object(14)
# memory usage: 572.0+ KB

# %%
df.info (memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_asociado       2524 non-null   int64
#  1   cedula            2524 non-null   int64
#  2   nombre            2524 non-null   object
#  3   antiguedad        2524 non-null   int64
#  4   activo            2524 non-null   object
#  5   ciudad            2524 non-null   object
#  6   edad              2524 non-null   int64
#  7   genero            2524 non-null   object
#  8   tipo_vivienda     2524 non-null   object
#  9   estrato           2524 non-null   int64
#  10  ocupacion         2524 non-null   object
#  11  nivel_academico   2524 non-null   object
#  12  no_hijos          2524 non-null   int64
#  13  personas_a_cargo  2524 non-null   object
#  14  tiene_casa        2524 non-null   object
#  15  tiene_carro       2524 non-null   object
#  16  estado_civil      2524 non-null   object
#  17  tipo_contrato     2524 non-null   object
#  18  activos           2524 non-null   int64
#  19  pasivos           2524 non-null   int64
#  20  patrimonio        2524 non-null   int64
#  21  salario           2524 non-null   int64
#  22  gastos            2524 non-null   int64
#  23  entidad           2524 non-null   object
#  24  no_productos      2524 non-null   int64
#  25  calificacion      2524 non-null   object
#  26  dias_mora         2524 non-null   int64
#  27  saldo_total       2524 non-null   float64
#  28  mora              2524 non-null   int64
# dtypes: float64(1), int64(14), object(14)
# memory usage: 2.4 MB

# %%
df.shape
# Out:
# (2524, 29)

# %%
df.set_index('no_asociado', inplace = True)
df
# Out:
#               cedula                          nombre  antiguedad  activo  \
# no_asociado
# 1              10000     JORGE ELIECER ALDANA AMADOR           4  Activo
# 2              11000     ELKIN ARLEY CASTRO VELANDIA           1  Activo
# 3              12000  HERSSON FERNANDO FLOREZ MORENO           6  Activo
# 4              13000  BRAYAN ALEXANDER BARON ORTEGON           0  Activo
# 5              14000    CINDY MAYELA OCHOA HERNANDEZ           5  Activo
# ...              ...                             ...         ...     ...
# 2520         2529000                    OFELIA PEREZ          21  Activo
# 2521         2530000      DORIS EDIT PARRADO PARRADO           7  Activo
# 2522         2531000    LUIS HERLEY JIMENEZ VALENCIA           6  Activo
# 2523         2532000  ANGELICA MARIA BLANCO QUINTERO          13  Activo
# 2524         2533000        LUIS MIGUEL DIAZ CUBIDES          21  Activo
#
#             ciudad  edad     genero tipo_vivienda  estrato  \
# no_asociado
# 1              GRA    54  Masculino     ARRENDADA        2
# 2             GRAN    29  Masculino        PROPIA        2
# 3             GRAN    29  Masculino      FAMILIAR        3
# 4              ACA    31  Masculino     ARRENDADA        2
# 5             GRAN    34   Femenino        PROPIA        2
# ...            ...   ...        ...           ...      ...
# 2520          GRAN    63   Femenino     ARRENDADA        2
# 2521          GRAN    56   Femenino        PROPIA        3
# 2522         VILLA    53  Masculino        PROPIA        3
# 2523         VILLA    43   Femenino        PROPIA        3
# 2524         VILLA    61  Masculino        PROPIA        3
#
#                                ocupacion  ...   pasivos  patrimonio  salario  \
# no_asociado                               ...
# 1                                DOCENTE  ...         1           0  1149906
# 2            EMPLEADO PUBLICO NO DOCENTE  ...  16000000           0  1228925
# 3                                DOCENTE  ...  84000000   -83999999  2319409
# 4                                Tecnico  ...         0           0  1854448
# 5                                DOCENTE  ...  67000000    83000000  2489102
# ...                                  ...  ...       ...         ...      ...
# 2520                               Otros  ...         0           0  1167812
# 2521                               Otros  ...         0           0  3300000
# 2522                               Otros  ...         0           0  2402900
# 2523                               Otros  ...         0           0  5872590
# 2524                               Otros  ...         0           0  2129772
#
#               gastos       entidad no_productos calificacion  dias_mora  \
# no_asociado
# 1            1000000        GOB MT            1            A          0
# 2            1000000      EJER NAL            1            A          0
# 3            1540000        GOB MT            1            A          0
# 4             900000  MPIO EL DORA            1            A          0
# 5            1000000        GOB MT            1            A          0
# ...              ...           ...          ...          ...        ...
# 2520               0             0            2            E        990
# 2521               0             0            1            E       1740
# 2522               0      MUN VCIO            6            E       1345
# 2523               0      MUN VCIO            3            E        865
# 2524               0             0            1            E       3630
#
#              saldo_total       mora
# no_asociado
# 1               492687.0          0
# 2               395715.0          0
# 3               603910.0          0
# 4               631766.0          0
# 5                    0.0          0
# ...                  ...        ...
# 2520          12678497.0   52220345
# 2521          26341773.0   55830006
# 2522          26442992.0   75132454
# 2523          17119909.0   78433507
# 2524          39753981.0  163603870
#
# [2524 rows x 28 columns]

# %%
df.columns.values
# Out:
# array(['cedula', 'nombre', 'antiguedad', 'activo', 'ciudad', 'edad',
#        'genero', 'tipo_vivienda', 'estrato', 'ocupacion',
#        'nivel_academico', 'no_hijos', 'personas_a_cargo', 'tiene_casa',
#        'tiene_carro', 'estado_civil', 'tipo_contrato', 'activos',
#        'pasivos', 'patrimonio', 'salario', 'gastos', 'entidad',
#        'no_productos', 'calificacion', 'dias_mora', 'saldo_total', 'mora'],
#       dtype=object)

# %%
df.columns.to_list()
# Out:
# ['cedula',
#  'nombre',
#  'antiguedad',
#  'activo',
#  'ciudad',
#  'edad',
#  'genero',
#  'tipo_vivienda',
#  'estrato',
#  'ocupacion',
#  'nivel_academico',
#  'no_hijos',
#  'personas_a_cargo',
#  'tiene_casa',
#  'tiene_carro',
#  'estado_civil',
#  'tipo_contrato',
#  'activos',
#  'pasivos',
#  'patrimonio',
#  'salario',
#  'gastos',
#  'entidad',
#  'no_productos',
#  'calificacion',
#  'dias_mora',
#  'saldo_total',
#  'mora']

# %%
df.dtypes
# Out:
# cedula                int64
# nombre               object
# antiguedad            int64
# activo               object
# ciudad               object
# edad                  int64
# genero               object
# tipo_vivienda        object
# estrato               int64
# ocupacion            object
# nivel_academico      object
# no_hijos              int64
# personas_a_cargo     object
# tiene_casa           object
# tiene_carro          object
# estado_civil         object
# tipo_contrato        object
# activos               int64
# pasivos               int64
# patrimonio            int64
# salario               int64
# gastos                int64
# entidad              object
# no_productos          int64
# calificacion         object
# dias_mora             int64
# saldo_total         float64
# mora                  int64
# dtype: object

# %%
df.describe(include='O').T
# Out:
#                  count unique                          top  freq
# nombre            2524   2524  JORGE ELIECER ALDANA AMADOR     1
# activo            2524      2                       Activo  2523
# ciudad            2524      5                         GRAN  1058
# genero            2524      2                     Femenino  1622
# tipo_vivienda     2524      4                       PROPIA  1258
# ocupacion         2524    201                        Otros   845
# nivel_academico   2524     11                Universitario   623
# personas_a_cargo  2524      6                          Una   695
# tiene_casa        2524      3                            0  2362
# tiene_carro       2524      3                            0  2363
# estado_civil      2524      8                      Soltero  1005
# tipo_contrato     2524      4        A tÃ©rmino Indefinido  1440
# entidad           2524     72                       GOB MT  1328
# calificacion      2524      5                            A  2391

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tipo_contrato.mode()
# Out:
# 0    A tÃ©rmino Indefinido
# dtype: object

# %%
df.isna().sum().sort_values()
# Out:
# cedula              0
# dias_mora           0
# calificacion        0
# no_productos        0
# entidad             0
# gastos              0
# salario             0
# patrimonio          0
# pasivos             0
# activos             0
# tipo_contrato       0
# estado_civil        0
# tiene_carro         0
# tiene_casa          0
# personas_a_cargo    0
# no_hijos            0
# nivel_academico     0
# ocupacion           0
# estrato             0
# tipo_vivienda       0
# genero              0
# edad                0
# ciudad              0
# activo              0
# antiguedad          0
# nombre              0
# saldo_total         0
# mora                0
# dtype: int64

# %%
print(df['mora'].max())
print(df['mora'].min())
print(df['mora'].mean())
print(df['mora'].median())
# Out:
# 163603870
# 0
# 1197997.4782091917
# 532156.0

# %%
missing_values_count = df.isna().sum()
missing_values_count
# Out:
# cedula              0
# nombre              0
# antiguedad          0
# activo              0
# ciudad              0
# edad                0
# genero              0
# tipo_vivienda       0
# estrato             0
# ocupacion           0
# nivel_academico     0
# no_hijos            0
# personas_a_cargo    0
# tiene_casa          0
# tiene_carro         0
# estado_civil        0
# tipo_contrato       0
# activos             0
# pasivos             0
# patrimonio          0
# salario             0
# gastos              0
# entidad             0
# no_productos        0
# calificacion        0
# dias_mora           0
# saldo_total         0
# mora                0
# dtype: int64

# %%
total_cell = np.product(df.shape)
total_missing = missing_values_count.sum()
(total_missing/total_cell)*100
# porcentaje de datos nulos
# Out:
# 0.0

# %%
msno.bar(df);
# La biblioteca Missingno ofrece una forma muy agradable de visualizar la distribución de los valores de NaN. 
# Missingno es una biblioteca de Python y compatible con Pandas.
# import missingno as msno
# grafica donde se visualizan los datos con valor y descuenta los nulos

# %%
msno.matrix(df);

# %%
df[df.isna().any(1)]
# Out:
# Empty DataFrame
# Columns: [cedula, nombre, antiguedad, activo, ciudad, edad, genero, tipo_vivienda, estrato, ocupacion, nivel_academico, no_hijos, personas_a_cargo, tiene_casa, tiene_carro, estado_civil, tipo_contrato, activos, pasivos, patrimonio, salario, gastos, entidad, no_productos, calificacion, dias_mora, saldo_total, mora]
# Index: []
#
# [0 rows x 28 columns]

# %%
# cuantos asociados activos hay?

df.count()['activos']
# Out:
# 2524

# %%
# cual es la mayor y menor antiguedad
print(df['antiguedad'].max())
print(df['antiguedad'].min())
print(df['antiguedad'].mean())
# Out:
# 36
# 0
# 7.457210776545167

# %%
# cual es la mayor y menor edad
print(df['edad'].max())
print(df['edad'].min())
print(df['edad'].mean())
# Out:
# 80
# 19
# 46.437797147385105

# %%
df.describe()
# Out:
#              cedula   antiguedad         edad      estrato     no_hijos  \
# count  2.524000e+03  2524.000000  2524.000000  2524.000000  2524.000000
# mean   1.271500e+06     7.457211    46.437797     2.188193     1.080032
# std    7.287604e+05     7.348318    11.717396     0.820759     1.266951
# min    1.000000e+04     0.000000    19.000000     0.000000     0.000000
# 25%    6.407500e+05     2.000000    37.000000     2.000000     0.000000
# 50%    1.271500e+06     5.000000    46.000000     2.000000     1.000000
# 75%    1.902250e+06    10.000000    55.000000     3.000000     2.000000
# max    2.533000e+06    36.000000    80.000000     6.000000    11.000000
#
#             activos       pasivos    patrimonio       salario        gastos  \
# count  2.524000e+03  2.524000e+03  2.524000e+03  2.524000e+03  2.524000e+03
# mean   2.199825e+08  2.793484e+07  1.908672e+08  3.181291e+06  1.392214e+06
# std    5.802217e+09  6.928200e+07  5.801899e+09  2.270543e+06  7.233586e+06
# min    0.000000e+00  0.000000e+00 -2.325000e+09  1.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  1.896063e+06  0.000000e+00
# 50%    5.000000e+06  9.650000e+05  0.000000e+00  2.633097e+06  7.550000e+05
# 75%    8.825000e+07  4.000000e+07  3.370000e+07  3.919989e+06  1.585000e+06
# max    2.500070e+11  2.500000e+09  2.499520e+11  5.091999e+07  3.015000e+08
#
#        no_productos    dias_mora   saldo_total          mora
# count   2524.000000  2524.000000  2.524000e+03  2.524000e+03
# mean       1.543185    28.992076  1.044385e+07  1.197997e+06
# std        0.775234   181.366893  1.972087e+07  4.587892e+06
# min        1.000000     0.000000  0.000000e+00  0.000000e+00
# 25%        1.000000     0.000000  6.055995e+05  2.355512e+05
# 50%        1.000000     0.000000  2.106686e+06  5.321560e+05
# 75%        2.000000     0.000000  1.044297e+07  1.253856e+06
# max        9.000000  3630.000000  2.573181e+08  1.636039e+08
