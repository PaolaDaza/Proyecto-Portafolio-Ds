# %%
import pandas as pd

# %%
df = pd.read_excel('./../data/analisis-creditos.xlsx')

# %%
df
# Out:
#       IDENTIFICACION                     NOMBRE_CLIENTE NOMBRE_AGENCIA  \
# 0              11000             DEYBIANER VELEZ QUIROZ            GDA
# 1              12000             DEYBIANER VELEZ QUIROZ            GDA
# 2              13000     ALEJANDRO RODULFO MONROY MATOS           VCIO
# 3              14000     ALEJANDRO RODULFO MONROY MATOS           VCIO
# 4              15000                ERICA ANDREA GARZON           VCIO
# ...              ...                                ...            ...
# 3888         3899000      JONATHAN EDUARDO RIVERA ARIZA            ACA
# 3889         3900000  CHRISTIAN CAMILO MOSQUERA SALCEDO            ACA
# 3890         3901000       LIBIA MERCEDES OROZCO ARCILA            GDA
# 3891         3902000          ETELVINA VARGAS MONDAGRON            GDA
# 3892         3903000            WILMER GARCIA RODRIGUEZ            GDA
#
#      TIPO_IDENTIFICACION                     NOMBRE_PRODUCTO  NUMERO_PRESTAMO  \
# ...

# %%
from janitor import clean_names
df = clean_names(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   identificacion                   3893 non-null   int64
#  1   nombre_cliente                   3893 non-null   object
#  2   nombre_agencia                   3893 non-null   object
#  3   tipo_identificacion              3893 non-null   object
#  4   nombre_producto                  3893 non-null   object
#  5   numero_prestamo                  3893 non-null   int64
#  6   garantia                         2639 non-null   object
#  7   estado_prestamo                  3893 non-null   object
#  8   tipo_prestamo                    3893 non-null   object
#  9   forma_pago                       3893 non-null   object
#  10  garantia_admisible               3893 non-null   int64
#  11  garantia_admisible_hipotecaria   3893 non-null   int64
# ...

# %%
df.info (memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   identificacion                   3893 non-null   int64
#  1   nombre_cliente                   3893 non-null   object
#  2   nombre_agencia                   3893 non-null   object
#  3   tipo_identificacion              3893 non-null   object
#  4   nombre_producto                  3893 non-null   object
#  5   numero_prestamo                  3893 non-null   int64
#  6   garantia                         2639 non-null   object
#  7   estado_prestamo                  3893 non-null   object
#  8   tipo_prestamo                    3893 non-null   object
#  9   forma_pago                       3893 non-null   object
#  10  garantia_admisible               3893 non-null   int64
#  11  garantia_admisible_hipotecaria   3893 non-null   int64
# ...

# %%
df.set_index('identificacion', inplace = True)
df
# Out:
#                                    nombre_cliente nombre_agencia  \
# identificacion
# 11000                      DEYBIANER VELEZ QUIROZ            GDA
# 12000                      DEYBIANER VELEZ QUIROZ            GDA
# 13000              ALEJANDRO RODULFO MONROY MATOS           VCIO
# 14000              ALEJANDRO RODULFO MONROY MATOS           VCIO
# 15000                         ERICA ANDREA GARZON           VCIO
# ...                                           ...            ...
# 3899000             JONATHAN EDUARDO RIVERA ARIZA            ACA
# 3900000         CHRISTIAN CAMILO MOSQUERA SALCEDO            ACA
# 3901000              LIBIA MERCEDES OROZCO ARCILA            GDA
# 3902000                 ETELVINA VARGAS MONDAGRON            GDA
# 3903000                   WILMER GARCIA RODRIGUEZ            GDA
#
#                tipo_identificacion                     nombre_producto  \
# identificacion
# 11000                         C.C.  001 - LIBRE INVERSION CON LIBRANZA
# ...

# %%
df.shape
# Out:
# (3893, 48)

# %%
df.columns.values
# Out:
# array(['nombre_cliente', 'nombre_agencia', 'tipo_identificacion',
#        'nombre_producto', 'numero_prestamo', 'garantia',
#        'estado_prestamo', 'tipo_prestamo', 'forma_pago',
#        'garantia_admisible', 'garantia_admisible_hipotecaria',
#        'tipo_de_garantia', 'dias_mora', 'calificacion_objetiva',
#        'dias_mora_arrastre', 'calificacion_arrastre',
#        'calificacion_subjetiva', 'calificacion_arrastre_subjetiva',
#        'calificacion_provision', 'saldo_aportes', 'proporcion_aporte',
#        'mora', 'saldo_capital', 'saldo_interes_corriente',
#        'saldo_interes_mora', 'saldo_otros_conceptos', 'saldo_total',
#        'provision_capital', 'provision_interes_corriente',
#        'provision_interes_mora', 'provision_otros_conceptos', 'plazo',
#        'interes_anticipado', 'fecha_inicio', 'fecha_desembolso',
#        'capital_inicial', 'interes_corriente_dc', 'interes_mora_dc',
#        'alivio_interes', 'alivio_cargos', 'reestructurado', 'aliviado',
# ...

# %%
df.columns.to_list()
# Out:
# ['nombre_cliente',
#  'nombre_agencia',
#  'tipo_identificacion',
#  'nombre_producto',
#  'numero_prestamo',
#  'garantia',
#  'estado_prestamo',
#  'tipo_prestamo',
#  'forma_pago',
#  'garantia_admisible',
#  'garantia_admisible_hipotecaria',
#  'tipo_de_garantia',
#  'dias_mora',
#  'calificacion_objetiva',
#  'dias_mora_arrastre',
#  'calificacion_arrastre',
#  'calificacion_subjetiva',
#  'calificacion_arrastre_subjetiva',
#  'calificacion_provision',
#  'saldo_aportes',
#  'proporcion_aporte',
#  'mora',
#  'saldo_capital',
#  'saldo_interes_corriente',
#  'saldo_interes_mora',
#  'saldo_otros_conceptos',
#  'saldo_total',
#  'provision_capital',
#  'provision_interes_corriente',
#  'provision_interes_mora',
#  'provision_otros_conceptos',
#  'plazo',
#  'interes_anticipado',
#  'fecha_inicio',
#  'fecha_desembolso',
#  'capital_inicial',
#  'interes_corriente_dc',
#  'interes_mora_dc',
#  'alivio_interes',
#  'alivio_cargos',
#  'reestructurado',
#  'aliviado',
# ...

# %%
df.dtypes
# Out:
# nombre_cliente                             object
# nombre_agencia                             object
# tipo_identificacion                        object
# nombre_producto                            object
# numero_prestamo                             int64
# garantia                                   object
# estado_prestamo                            object
# tipo_prestamo                              object
# forma_pago                                 object
# garantia_admisible                          int64
# garantia_admisible_hipotecaria              int64
# tipo_de_garantia                           object
# dias_mora                                   int64
# calificacion_objetiva                      object
# dias_mora_arrastre                          int64
# calificacion_arrastre                      object
# calificacion_subjetiva                     object
# calificacion_arrastre_subjetiva            object
# calificacion_provision                     object
# ...

# %%
df.describe(include='O').T
# Out:
#                                 count unique  \
# nombre_cliente                   3893   2524
# nombre_agencia                   3893      4
# tipo_identificacion              3893      1
# nombre_producto                  3893     27
# garantia                         2639      6
# estado_prestamo                  3893      1
# tipo_prestamo                    3893      3
# forma_pago                       3893      4
# tipo_de_garantia                 2199      2
# calificacion_objetiva            3893      5
# calificacion_arrastre            3893      5
# calificacion_subjetiva             31      4
# calificacion_arrastre_subjetiva    35      4
# calificacion_provision           3893      5
# reestructurado                   2776      2
# aliviado                         3893      2
#
#                                                                 top  freq
# nombre_cliente                           ROSA ELENA CARDOZO HERMOSA     9
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tipo_prestamo.mode()
# Out:
# 0    Consumo
# dtype: object

# %%
df.isna().sum().sort_values()
# Out:
# nombre_cliente                        0
# saldo_otros_conceptos                 0
# saldo_total                           0
# provision_capital                     0
# provision_interes_corriente           0
# provision_interes_mora                0
# provision_otros_conceptos             0
# plazo                                 0
# interes_anticipado                    0
# fecha_inicio                          0
# capital_inicial                       0
# interes_corriente_dc                  0
# interes_mora_dc                       0
# alivio_interes                        0
# alivio_cargos                         0
# aliviado                              0
# saldo_alicuota_interes_julio31        0
# saldo_alicuota_cargos_julio31         0
# garantia_admisible_finagro            0
# garantia_admisible_fondo              0
# saldo_interes_mora                    0
# interes_cte_af_gcp                    0
# saldo_interes_corriente               0
# ...

# %%
print(df['dias_mora'].max())
print(df['dias_mora'].min())
print(df['dias_mora'].mean())
print(df['dias_mora'].median())
# Out:
# 3630
# 0
# 32.12072951451323
# 0.0

# %% [markdown]
# ##

# %%
from pandas_profiling import ProfilingReport
informe = ProfilingReport(df)
informe.to_file('creditos.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13160/598031379.py in <module>
# ----> 1 from pandas_profiling import ProfilingReport
#       2 informe = ProfilingReport(df)
#       3 informe.to_file('creditos.html')
#
# ImportError: cannot import name 'ProfilingReport' from 'pandas_profiling' (C:\Users\USUARIO\anaconda3\lib\site-packages\pandas_profiling\__init__.py)

# %%
df.describe()
# Out:
#        numero_prestamo  garantia_admisible  garantia_admisible_hipotecaria  \
# count     3.893000e+03        3.893000e+03                    3.893000e+03
# mean      1.460233e+09        5.635981e+05                    2.511642e+05
# std       8.396943e+08        2.992503e+06                    4.986732e+06
# min       4.041528e+07        0.000000e+00                    0.000000e+00
# 25%       2.012724e+08        0.000000e+00                    0.000000e+00
# 50%       2.020002e+09        0.000000e+00                    0.000000e+00
# 75%       2.020004e+09        0.000000e+00                    0.000000e+00
# max       2.020006e+09        7.920000e+07                    1.700000e+08
#
#          dias_mora  dias_mora_arrastre  saldo_aportes  proporcion_aporte  \
# count  3893.000000         3893.000000   3.893000e+03       3.893000e+03
# mean     32.120730           35.292320   2.867596e+06       1.097069e+06
# ...
